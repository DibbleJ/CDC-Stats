# %% [markdown]
# The data file bd.data.0.Current.txt is too large to upload to GitHub. Data found here https://download.bls.gov/pub/time.series/bd/

# %%
import pandas as pd

# %%
FBI = pd.read_excel("FBI.xls",skiprows=3)
FBI = FBI.drop(FBI.index[20:],0)
FBI = FBI.set_index("Year")
FBI.columns = FBI.columns.str.replace('\n',' ')
FBI
# Out:
#        Population1  Violent crime2 Violent  crime  rate   \
# Year
# 1997   267783607.0       1636096.0                   611
# 1998   270248003.0       1533887.0                 567.6
# 1999   272690813.0       1426044.0                   523
# 2000   281421906.0       1425486.0                 506.5
# 20015  285317559.0       1439480.0                 504.5
# 2002   287973924.0       1423677.0                 494.4
# 2003   290788976.0       1383676.0                 475.8
# 2004   293656842.0       1360088.0                 463.2
# 2005   296507061.0       1390745.0                   469
# 2006   299398484.0       1435123.0                 479.3
# 2007   301621157.0       1422970.0                 471.8
# 2008   304059724.0       1394461.0                 458.6
# 2009   307006550.0       1325896.0                 431.9
# 2010   309330219.0       1251248.0                 404.5
# 2011   311587816.0       1206005.0                 387.1
# ...

# %%
FBI.iloc[1]
# Out:
# Population1                                      270248003.0
# Violent crime2                                     1533887.0
# Violent  crime  rate                                   567.6
# Murder and nonnegligent  manslaughter                16974.0
# Murder and  nonnegligent  manslaughter  rate             6.3
# Rape (revised  definition3)                              NaN
# Rape (revised  definition)  rate3                        NaN
# Rape (legacy  definition4)                           93144.0
# Rape (legacy  definition)  rate4                        34.5
# Robbery                                             447186.0
# Robbery  rate                                          165.5
# Aggravated  assault                                 976583.0
# Aggravated  assault rate                               361.4
# Property  crime                                   10951827.0
# Property  crime  rate                                 4052.5
# ...

# %%
FBI.isna().sum()
# Out:
# Population1                                          0
# Violent\ncrime2                                      0
# Violent \ncrime \nrate                               0
# Murder and\nnonnegligent \nmanslaughter              0
# Murder and \nnonnegligent \nmanslaughter \nrate      0
# Rape\n(revised \ndefinition3)                       15
# Rape\n(revised \ndefinition) \nrate3                16
# Rape\n(legacy \ndefinition4)                         0
# Rape\n(legacy \ndefinition) \nrate4                  0
# Robbery                                              0
# Robbery \nrate                                       0
# Aggravated \nassault                                 0
# Aggravated \nassault rate                            0
# Property \ncrime                                     0
# Property \ncrime \nrate                              0
# Burglary                                             0
# Burglary \nrate                                      0
# ...
